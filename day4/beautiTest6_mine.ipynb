# %%
from bs4 import BeautifulSoup
import urllib.request as REQ
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import warnings
import urllib.request as REQ
import folium                    #python 지도 library
import json
import urllib
warnings.simplefilter('ignore')
matplotlib.rcParams['font.family']='Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus']=False

# %%
nurl = 'https://www.menupan.com/restaurant/bestrest/bestrest.asp?pt=rt&areacode=ss212'
response = REQ.urlopen(nurl)
soup = BeautifulSoup(response, 'html.parser')
soup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <html xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <title>맛집TOP1000 - 매일매일 맛있게 메뉴판닷컴</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <link href="/common/css/default.css" rel="stylesheet" type="text/css"/>
# <link href="/common/style/restaurant/bestrest.css" rel="stylesheet" type="text/css"/>
# <script language="javascript" src="/script/jquery/jquery-latest.min.js"></script>
# <script language="javascript">
# 	<!--
# 		//-- hide all layer
# 		function fn_close_all_layer() {
# 			fn_disp_layer_standard('hide');
# 			fn_disp_layer_type('hide');
# 		}
# 		//-- show information
# 		function fn_disp_layer_standard(p_cmd) {
# 			if (p_cmd == 'show') {
# 				fn_close_all_layer();
# 				$('#id_lyr_standard').show();
# 			}
# 			else if (p_cmd == 'hide') {
# 				$('#id_lyr_standard').hide();
# 			}
# 		}
# 		//-- show type select
# ...

# %%
restaurants = soup.select('.rankingList')
# print(restaurants)
for rest in restaurants:
    rest_names = rest.select('.listName a')
    for rest_name in rest_names:
        print(rest_name.string)
# Out:
# 타이쇼(TAISHO)
# 비어드파파(BEARD PAPAS)
# 그집
# 제주흑다돈 양재직영점
# 커피세레모니(COFFEE CEREMONY)
# 쌈플러스 양재본점
# 참설농탕
# 화돌농장
# 한국관(도곡점)
# 벽제갈비
# 쌈겹(ssamgyeop)
# 앨리스토리(Alleystory)
# 블랙머그 도곡점
# 허브분식 본점
# 스타쉐프(Star Chef)
# 아웃도어셰프
# 콜라겐팩토리
# 해조
# 개성족발
# 청담이상(LEE SANG) 양재점
# 율리
# 남우정 양재본점
# 논골집
# 청정바다수산
# 오가네족발

# %%
ul = soup.select_one('.rankingList > .list')
for li in ul.select('li'):
    print(li)
# Out:
# <li>
# <div class="listRank">
# <p class="numTop">1</p>
# <p class="fluc"><span class="same">same</span></p>
# </div>
# <p class="listPhoto"><a href="/restaurant/onepage.asp?acode=D102869" target="_blank"><img alt="" onerror="this.src='/image/restaurant/bestrest/noimg_50.gif'" src="/restaurant/restimg/009/ssimg/d102869a_s.jpg"/></a></p>
# <p class="listName"><span class="restName"><a href="/restaurant/onepage.asp?acode=D102869" target="_blank">타이쇼(TAISHO)</a></span></p>
# <p class="listType">카페/주점</p>
# <p class="listArea">강남구 도곡동</p>
# <p class="listService">
# <img alt="프리쿠폰" src="/image/restaurant/bestrest/ic_coupon.gif"/>
# </p>
# </li>
# <li>
# <div class="listRank">
# <p class="numTop">2</p>
# <p class="fluc"><span class="up">3</span></p>
# </div>
# <p class="listPhoto"><a href="/restaurant/onepage.asp?acode=D103228" target="_blank"><img alt="" onerror="this.src='/image/restaurant/bestrest/noimg_50.gif'" src="/restaurant/restimg/008/ssimg/d103228a_s.jpg"/></a></p>
# ...

# %%
ul = soup.select_one('.rankingList > .list')
for li in ul.select('li'):
    print(li.select_one('.numTop,.rankNum').string)
    print(li.select_one('.listName').string)
    print(li.select_one('.listType').string)
    print(li.select_one('.listArea').string)
    print("=" * 30)
# Out:
# 1
# 타이쇼(TAISHO)
# 카페/주점
# 강남구 도곡동
# ...
# 2
# 비어드파파(BEARD PAPAS)
# 카페/주점
# 서초구 양재동
# ...
# 3
# 그집
# 카페/주점
# 서초구 양재동
# ...
# 4
# 제주흑다돈 양재직영점
# 한식
# 서초구 양재2동
# ...
# 5
# 커피세레모니(COFFEE CEREMONY)
# 카페/주점
# 서초구 양재동
# ...
# 6
# 쌈플러스 양재본점
# 한식
# 서초구 양재동
# ...
# 7
# 참설농탕
# 한식
# 서초구 서초동
# ...
# 8
# 화돌농장
# 한식
# 서초구 양재2동
# ...
# 9
# 한국관(도곡점)
# 한식
# 강남구 도곡동
# ...
# 10
# 벽제갈비
# 한식
# 강남구 도곡동
# ...
# 11
# 쌈겹(ssamgyeop)
# 한식
# 서초구 양재동
# ...
# 12
# 앨리스토리(Alleystory)
# 카페/주점
# 서초구 양재2동
# ...
# 13
# 블랙머그 도곡점
# 카페/주점
# 강남구 도곡동
# ...
# 14
# 허브분식 본점
# 분식
# 강남구 도곡동
# ...
# 15
# 스타쉐프(Star Chef)
# 기타/세계
# 강남구 도곡동
# ...
# 16
# 아웃도어셰프
# 일식
# 서초구 양재동
# ...
# 17
# 콜라겐팩토리
# 한식
# 서초구 양재동
# ...
# 18
# 해조
# 일식
# 서초구 양재2동
# ...
# 19
# 개성족발
# 한식
# 서초구 양재2동
# ...
# 20
# 청담이상(LEE SANG) 양재점
# 일식
# 서초구 양재1동
# ...
# 21
# 율리
# 카페/주점
# 서초구 양재동
# ...
# 22
# 남우정 양재본점
# 한식
# 서초구 양재2동
# ...
# 23
# 논골집
# 한식
# 강남구 개포동
# ...
# 24
# 청정바다수산
# 한식
# 서초구 양재동
# ...
# 25
# 오가네족발
# 한식
# 강남구 도곡동
# ...

# %%
listData = []
for li in ul.select('li'):
    listRank = li.select_one('.numTop,.rankNum').string
    listName = li.select_one('.listName').string
    listType = li.select_one('.listType').string
    listArea = li.select_one('.listArea').string
    listData.append({"랭킹": listRank,
                     "상호명": listName,
                     "업종": listType,
                     "지역": listArea
                    })
listData
# Out:
# [{'랭킹': '1', '상호명': '타이쇼(TAISHO)', '업종': '카페/주점', '지역': '강남구 도곡동'},
#  {'랭킹': '2', '상호명': '비어드파파(BEARD PAPAS)', '업종': '카페/주점', '지역': '서초구 양재동'},
#  {'랭킹': '3', '상호명': '그집', '업종': '카페/주점', '지역': '서초구 양재동'},
#  {'랭킹': '4', '상호명': '제주흑다돈 양재직영점', '업종': '한식', '지역': '서초구 양재2동'},
#  {'랭킹': '5', '상호명': '커피세레모니(COFFEE CEREMONY)', '업종': '카페/주점', '지역': '서초구 양재동'},
#  {'랭킹': '6', '상호명': '쌈플러스 양재본점', '업종': '한식', '지역': '서초구 양재동'},
#  {'랭킹': '7', '상호명': '참설농탕', '업종': '한식', '지역': '서초구 서초동'},
#  {'랭킹': '8', '상호명': '화돌농장', '업종': '한식', '지역': '서초구 양재2동'},
#  {'랭킹': '9', '상호명': '한국관(도곡점)', '업종': '한식', '지역': '강남구 도곡동'},
#  {'랭킹': '10', '상호명': '벽제갈비', '업종': '한식', '지역': '강남구 도곡동'},
#  {'랭킹': '11', '상호명': '쌈겹(ssamgyeop)', '업종': '한식', '지역': '서초구 양재동'},
#  {'랭킹': '12', '상호명': '앨리스토리(Alleystory)', '업종': '카페/주점', '지역': '서초구 양재2동'},
#  {'랭킹': '13', '상호명': '블랙머그 도곡점', '업종': '카페/주점', '지역': '강남구 도곡동'},
#  {'랭킹': '14', '상호명': '허브분식 본점', '업종': '분식', '지역': '강남구 도곡동'},
# ...

# %%
df = pd.DataFrame(listData)
df
# Out:
#     랭킹                      상호명     업종        지역
# 0    1              타이쇼(TAISHO)  카페/주점   강남구 도곡동
# 1    2       비어드파파(BEARD PAPAS)  카페/주점   서초구 양재동
# 2    3                       그집  카페/주점   서초구 양재동
# 3    4              제주흑다돈 양재직영점     한식  서초구 양재2동
# 4    5  커피세레모니(COFFEE CEREMONY)  카페/주점   서초구 양재동
# 5    6                쌈플러스 양재본점     한식   서초구 양재동
# 6    7                     참설농탕     한식   서초구 서초동
# 7    8                     화돌농장     한식  서초구 양재2동
# 8    9                 한국관(도곡점)     한식   강남구 도곡동
# 9   10                     벽제갈비     한식   강남구 도곡동
# 10  11            쌈겹(ssamgyeop)     한식   서초구 양재동
# 11  12        앨리스토리(Alleystory)  카페/주점  서초구 양재2동
# 12  13                 블랙머그 도곡점  카페/주점   강남구 도곡동
# 13  14                  허브분식 본점     분식   강남구 도곡동
# 14  15          스타쉐프(Star Chef)  기타/세계   강남구 도곡동
# 15  16                   아웃도어셰프     일식   서초구 양재동
# 16  17                   콜라겐팩토리     한식   서초구 양재동
# 17  18                       해조     일식  서초구 양재2동
# ...

# %%
df.set_index('랭킹', inplace=True)
df
# Out:
#                         상호명     업종        지역
# 랭킹
# 1               타이쇼(TAISHO)  카페/주점   강남구 도곡동
# 2        비어드파파(BEARD PAPAS)  카페/주점   서초구 양재동
# 3                        그집  카페/주점   서초구 양재동
# 4               제주흑다돈 양재직영점     한식  서초구 양재2동
# 5   커피세레모니(COFFEE CEREMONY)  카페/주점   서초구 양재동
# 6                 쌈플러스 양재본점     한식   서초구 양재동
# 7                      참설농탕     한식   서초구 서초동
# 8                      화돌농장     한식  서초구 양재2동
# 9                  한국관(도곡점)     한식   강남구 도곡동
# 10                     벽제갈비     한식   강남구 도곡동
# 11            쌈겹(ssamgyeop)     한식   서초구 양재동
# 12        앨리스토리(Alleystory)  카페/주점  서초구 양재2동
# 13                 블랙머그 도곡점  카페/주점   강남구 도곡동
# 14                  허브분식 본점     분식   강남구 도곡동
# 15          스타쉐프(Star Chef)  기타/세계   강남구 도곡동
# 16                   아웃도어셰프     일식   서초구 양재동
# 17                   콜라겐팩토리     한식   서초구 양재동
# 18                       해조     일식  서초구 양재2동
# 19                     개성족발     한식  서초구 양재2동
# 20       청담이상(LEE SANG) 양재점     일식  서초구 양재1동
# ...

# %%
# 전화번호 및 주소 추가를 위해 url 분리

burl = 'https://www.menupan.com'
surl = '/restaurant/bestrest/bestrest.asp?pt=rt&areacode=ss212'
response = REQ.urlopen(burl + surl)
soup = BeautifulSoup(response, 'html.parser')
# soup
listData = []
# saves anchor
href = []
for li in ul.select('li'):
    href.append(li.select_one('.listName a')['href']) # 식당 정보 획득을 위한 url 저장
    listRank = li.select_one('.numTop,.rankNum').string
    listName = li.select_one('.listName').string
    listType = li.select_one('.listType').string
    listArea = li.select_one('.listArea').string
    listData.append({"랭킹": listRank,
                     "상호명": listName,
                     "업종": listType,
                     "지역": listArea
                    })
df = pd.DataFrame(listData)

tel = []
addr = []
for h in href:
    response = REQ.urlopen(burl + h)
    soup = BeautifulSoup(response, 'html.parser')
    t = soup.select_one('.tel1').string
    a = soup.select_one('.add1').string
    tel.append(t)
    addr.append(a)
    print(t)
    print(a)
df['전화번호'] = tel
df['주소'] = addr
# Out:
# (02) 577-2453
# 서울 강남구 도곡동 957-1 지하1층
# (02) 3461-2987
# 서울 서초구 양재동 12-10 한신휴플러스102호
# (02) 574-8548
# 서울 서초구 양재동 8-55
# (02) 3462-5292
# 서울 서초구 양재2동 316-2
# (070) 4116-0549
# 서울 서초구 양재동 400-13
# (02) 579-6393
# 서울 서초구 양재동 267-4
# (02) 3471-2488
# 서울 서초구 서초동 1340 대명빌딜 103호
# (02) 3462-5292
# 서울 서초구 양재2동 316-2
# (02) 3462-5450
# 서울 강남구 도곡동 193-40
# (02) 2058-3535
# 서울 강남구 도곡동 467-29 타워팰리스 반트 1층
# (02) 575-9291
# 서울 서초구 양재동 11-64
# (02) 6405-7774
# 서울 서초구 양재2동 319-4
# (02) 572-2214
# 서울 강남구 도곡동 542-6
# (02) 573-5756
# 서울 강남구 도곡동 953-1 지하1층
# (02) 529-8248
# 서울 강남구 도곡동 417-2
# (070) 8128-8938
# 서울 서초구 양재동 9-3
# (02) 579-8883
# 서울 서초구 양재동 94-9
# (02) 571-2033
# 서울 서초구 양재2동 351-2
# (02) 529-1966
# 서울 서초구 양재2동 316-3
# (02) 575-0542
# 서울 서초구 양재1동 91-5 엘류빌딩1.2층
# (02) 3461-3933
# 서울 서초구 양재동 15-28
# (02) 579-5826
# 서울 서초구 양재2동 301
# (02) 3461-7071
# 서울 강남구 개포동 1197
# (02) 575-4426
# 서울 서초구 양재동 326-7
# (02) 575-6607
# 서울 강남구 도곡동 416-11

# %%
df
# Out:
#     랭킹                      상호명     업종        지역             전화번호  \
# 0    1              타이쇼(TAISHO)  카페/주점   강남구 도곡동    (02) 577-2453
# 1    2       비어드파파(BEARD PAPAS)  카페/주점   서초구 양재동   (02) 3461-2987
# 2    3                       그집  카페/주점   서초구 양재동    (02) 574-8548
# 3    4              제주흑다돈 양재직영점     한식  서초구 양재2동   (02) 3462-5292
# 4    5  커피세레모니(COFFEE CEREMONY)  카페/주점   서초구 양재동  (070) 4116-0549
# 5    6                쌈플러스 양재본점     한식   서초구 양재동    (02) 579-6393
# 6    7                     참설농탕     한식   서초구 서초동   (02) 3471-2488
# 7    8                     화돌농장     한식  서초구 양재2동   (02) 3462-5292
# 8    9                 한국관(도곡점)     한식   강남구 도곡동   (02) 3462-5450
# 9   10                     벽제갈비     한식   강남구 도곡동   (02) 2058-3535
# 10  11            쌈겹(ssamgyeop)     한식   서초구 양재동    (02) 575-9291
# 11  12        앨리스토리(Alleystory)  카페/주점  서초구 양재2동   (02) 6405-7774
# 12  13                 블랙머그 도곡점  카페/주점   강남구 도곡동    (02) 572-2214
# ...

# %%
df.to_excel('menu.xlsx')

# %%
# 업종이 한식
# 지역이 양재인 데이터 출력
korean_food = df[df['업종'] == '한식']
korean_food
# Out:
#     랭킹            상호명  업종        지역            전화번호  \
# 3    4    제주흑다돈 양재직영점  한식  서초구 양재2동  (02) 3462-5292
# 5    6      쌈플러스 양재본점  한식   서초구 양재동   (02) 579-6393
# 6    7           참설농탕  한식   서초구 서초동  (02) 3471-2488
# 7    8           화돌농장  한식  서초구 양재2동  (02) 3462-5292
# 8    9       한국관(도곡점)  한식   강남구 도곡동  (02) 3462-5450
# 9   10           벽제갈비  한식   강남구 도곡동  (02) 2058-3535
# 10  11  쌈겹(ssamgyeop)  한식   서초구 양재동   (02) 575-9291
# 16  17         콜라겐팩토리  한식   서초구 양재동   (02) 579-8883
# 18  19           개성족발  한식  서초구 양재2동   (02) 529-1966
# 21  22       남우정 양재본점  한식  서초구 양재2동   (02) 579-5826
# 22  23            논골집  한식   강남구 개포동  (02) 3461-7071
# 23  24         청정바다수산  한식   서초구 양재동   (02) 575-4426
# 24  25          오가네족발  한식   강남구 도곡동   (02) 575-6607
#
#                                주소
# 3               서울 서초구 양재2동 316-2
# 5                서울 서초구 양재동 267-4
# 6       서울 서초구 서초동 1340 대명빌딜 103호
# 7               서울 서초구 양재2동 316-2
# 8               서울 강남구 도곡동 193-40
# ...

# %%
yangjae = df[df['지역'].str.contains('양재')]
yangjae
# Out:
#     랭킹                      상호명     업종        지역             전화번호  \
# 1    2       비어드파파(BEARD PAPAS)  카페/주점   서초구 양재동   (02) 3461-2987
# 2    3                       그집  카페/주점   서초구 양재동    (02) 574-8548
# 3    4              제주흑다돈 양재직영점     한식  서초구 양재2동   (02) 3462-5292
# 4    5  커피세레모니(COFFEE CEREMONY)  카페/주점   서초구 양재동  (070) 4116-0549
# 5    6                쌈플러스 양재본점     한식   서초구 양재동    (02) 579-6393
# 7    8                     화돌농장     한식  서초구 양재2동   (02) 3462-5292
# 10  11            쌈겹(ssamgyeop)     한식   서초구 양재동    (02) 575-9291
# 11  12        앨리스토리(Alleystory)  카페/주점  서초구 양재2동   (02) 6405-7774
# 15  16                   아웃도어셰프     일식   서초구 양재동  (070) 8128-8938
# 16  17                   콜라겐팩토리     한식   서초구 양재동    (02) 579-8883
# 17  18                       해조     일식  서초구 양재2동    (02) 571-2033
# 18  19                     개성족발     한식  서초구 양재2동    (02) 529-1966
# 19  20       청담이상(LEE SANG) 양재점     일식  서초구 양재1동    (02) 575-0542
# ...

# %%
map = folium.Map(location=[37.5012748, 127.039625], zoom_start=14)
mk = folium.Marker([37.5012748, 127.039625], popup='test')
mk.add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def addrToLatLng(s):
    client_id = "ppihLuN2pr20zbkL0CAJ"
    client_secret = "OJqch1hs7D"
    encText = urllib.parse.quote(s)
    url = "https://openapi.naver.com/v1/map/geocode?query=" + encText # json 결과
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        aa= response_body.decode('utf-8') 
        bb = json.loads(aa)
        return bb['result']['items'][0]['point']
    else:
        return "Error Code:" + rescode

# %%
for a in df['주소']:
    print(a)
    print(addrToLatLng(a))
# Out:
# 서울 강남구 도곡동 957-1 지하1층
# {'x': 127.035221, 'y': 37.4852592}
# 서울 서초구 양재동 12-10 한신휴플러스102호
# {'x': 127.0350358, 'y': 37.4841661}
# 서울 서초구 양재동 8-55
# {'x': 127.0383798, 'y': 37.4836759}
# 서울 서초구 양재2동 316-2
# {'x': 127.0393564, 'y': 37.4704448}
# 서울 서초구 양재동 400-13
# {'x': 127.0489284, 'y': 37.4718461}
# 서울 서초구 양재동 267-4
# {'x': 127.0434762, 'y': 37.476105}
# 서울 서초구 서초동 1340 대명빌딜 103호
# {'x': 127.0302824, 'y': 37.4887898}
# 서울 서초구 양재2동 316-2
# {'x': 127.0393564, 'y': 37.4704448}
# 서울 강남구 도곡동 193-40
# {'x': 127.0449445, 'y': 37.4869261}
# 서울 강남구 도곡동 467-29 타워팰리스 반트 1층
# {'x': 127.0528363, 'y': 37.4873383}
# 서울 서초구 양재동 11-64
# {'x': 127.0371685, 'y': 37.4839924}
# 서울 서초구 양재2동 319-4
# {'x': 127.0399664, 'y': 37.470824}
# 서울 강남구 도곡동 542-6
# {'x': 127.0437958, 'y': 37.4930135}
# 서울 강남구 도곡동 953-1 지하1층
# {'x': 127.0344138, 'y': 37.4853103}
# 서울 강남구 도곡동 417-2
# {'x': 127.0448904, 'y': 37.4852433}
# 서울 서초구 양재동 9-3
# {'x': 127.0385706, 'y': 37.4825544}
# 서울 서초구 양재동 94-9
# ...

# %%
# zip 함수에 대해
a = [1, 2, 3, 4]
b = [11, 22, 33, 44]
c = [111, 222, 333, 444]
z = zip(a, b, c)
print(list(z))
# Out:
# [(1, 11, 111), (2, 22, 222), (3, 33, 333), (4, 44, 444)]

# %%
map = folium.Map(location=[37.5012748, 127.039625], zoom_start=14)
for sangho, address in zip(df['상호명'], df['주소']):
    d = addrToLatLng(address)
    mk = folium.Marker([d['y'], d['x']], popup=sangho)
    mk.add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
