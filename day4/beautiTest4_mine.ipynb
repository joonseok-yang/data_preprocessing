# %%
from bs4 import BeautifulSoup
import urllib.request as REQ

# %%
nurl = 'https://news.naver.com'
response = REQ.urlopen(nurl)
soup = BeautifulSoup(response, 'html.parser')
soup
# Out:
# <!DOCTYPE HTML>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta contents="always" name="referrer"/>
# <meta content="600" http-equiv="refresh">
# <meta content="width=1106" name="viewport">
# <meta content="네이버 뉴스" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="http://news.naver.com/main/home.nhn" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_200x200_20160804.png" property="og:image">
# <meta content="정치, 경제, 사회, 생활/문화, 세계, IT/과학 등 언론사별, 분야별 뉴스 기사 제공" property="og:description"/>
# <meta content="네이버" property="og:article:author">
# <meta content="summary" name="twitter:card"/>
# <meta content="네이버 뉴스" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# <meta content="네이버 뉴스" name="twitter:creator"/>
# ...

# %%
soup.select('.newsnow_tx_inner strong')
# Out:
# [<strong>[4·3보선]민심 경고등 확인한 文…국정 운영 부담 더 커질 듯</strong>,
#  <strong>경상수지 흑자, 불안한 흐름…수출입 동반 부진</strong>,
#  <strong>세계 최초 5G 상용화 코 앞…어떤 의미 가지나</strong>,
#  <strong>교육위, '독도 일본땅' 담은 日교과서 시정 촉구 결의안 의결</strong>,
#  <strong>강풍 속 건조특보 '화재 주의'…낮 기온 올라</strong>,
#  <strong>로이킴도 단톡방에 음란물 올려…정보통신망법 위반 입건</strong>,
#  <strong>'불쾌한 손' 논란 바이든 "개인 공간 존중 유념하겠다"</strong>,
#  <strong>방미 외교안보라인 속속 귀국길…한미정상회담 사전조율 주목</strong>,
#  <strong>병원 예약이 새벽4시···MRI 건보에 환자 장사진 풍경</strong>,
#  <strong>"30대 기업 임원 4명중 1명은 '해외파'…평균 연령 53세"</strong>]

# %%
short_titles = soup.select('.newsnow_tx_inner strong')

for t in short_titles:
    print(t.string)
# Out:
# [4·3보선]민심 경고등 확인한 文…국정 운영 부담 더 커질 듯
# 경상수지 흑자, 불안한 흐름…수출입 동반 부진
# 세계 최초 5G 상용화 코 앞…어떤 의미 가지나
# 교육위, '독도 일본땅' 담은 日교과서 시정 촉구 결의안 의결
# 강풍 속 건조특보 '화재 주의'…낮 기온 올라
# 로이킴도 단톡방에 음란물 올려…정보통신망법 위반 입건
# '불쾌한 손' 논란 바이든 "개인 공간 존중 유념하겠다"
# 방미 외교안보라인 속속 귀국길…한미정상회담 사전조율 주목
# 병원 예약이 새벽4시···MRI 건보에 환자 장사진 풍경
# "30대 기업 임원 4명중 1명은 '해외파'…평균 연령 53세"
