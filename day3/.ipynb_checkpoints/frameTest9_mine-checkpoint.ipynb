# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import warnings
matplotlib.rcParams['font.family']='Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus']=False
warnings.simplefilter('ignore')

# %%
def get_data():
    return [[10, 20], [30, 40], [50, 60], [70, 80]]

def get_data_frame():
    data = [[10, 20], [30, 40], [50, 60], [70, 80]]
    return pd.DataFrame(data)

def get_dict_list():
    return [{'kor': 10, 'eng': 20}, {'kor': 30, 'eng': 40}, 
            {'kor': 50, 'eng': 60}, {'kor': 70, 'eng': 80}]

def get_dict():
    return {"kor": [10, 30, 50, 70], "eng": [20, 40, 60, 80],
           'math': [33, 44, 55, 66]}

def get_dict_data_frame():
    return pd.DataFrame(get_dict(), index=['a', 'b', 'c', 'd'])

# %%
# 추가
df = get_dict_data_frame()
df
# Out:
#    kor  eng  math
# a   10   20    33
# b   30   40    44
# c   50   60    55
# d   70   80    66

# %%
df.plot(kind='bar')
plt.show()

# %%
df['kor'].dtype
# Out:
# dtype('int64')

# %%
df['kor'] = df['kor'].astype(float)    # str, float, int

# %%
df
# Out:
#     kor  eng  math
# a  10.0   20    33
# b  30.0   40    44
# c  50.0   60    55
# d  70.0   80    66

# %%
df = df.astype(float)       # change whole data frame type

# %%
df
# Out:
#     kor   eng  math
# a  10.0  20.0  33.0
# b  30.0  40.0  44.0
# c  50.0  60.0  55.0
# d  70.0  80.0  66.0

# %%
df['eng'] = df['eng'].astype(str)

# %%
df
# Out:
#     kor   eng  math
# a  10.0  20.0  33.0
# b  30.0  40.0  44.0
# c  50.0  60.0  55.0
# d  70.0  80.0  66.0

# %%
df['eng']
# Out:
# a    20.0
# b    40.0
# c    60.0
# d    80.0
# Name: eng, dtype: object

# %%
df['eng'] + 'abc'
# Out:
# a    20.0abc
# b    40.0abc
# c    60.0abc
# d    80.0abc
# Name: eng, dtype: object

# %%
# df = pd.read_table(r'births.txt', usecols=['year', 'boy_num', 'girl_num'])
df = pd.read_table(r'births.txt', sep=',', index_col=0, header=None, )
df.columns = ["boys", "girls"]
df.index.name = 'year'
df
# Out:
#          boys    girls
# year
# 1880    90993   110491
# 1881    91954   100745
# 1882   107850   113688
# 1883   112321   104629
# 1884   129022   114445
# 1885   133055   107800
# 1886   144535   110784
# 1887   145982   101414
# 1888   178627   120853
# 1889   178366   110584
# 1890   190377   111025
# 1891   185482   101196
# 1892   212346   122037
# 1893   212906   112317
# 1894   222922   115772
# 1895   233630   117398
# 1896   237920   119570
# 1897   234202   112758
# 1898   258770   122693
# 1899   233023   106212
# 1900   299828   150499
# 1901   239348   106471
# 1902   264077   122659
# 1903   261973   119234
# 1904   275371   128125
# 1905   291629   132319
# 1906   295303   133159
# 1907   318566   146833
# 1908   334313   154344
# 1909   347228   163999
# ...       ...      ...
# 1982  1692678  1813970
# 1983  1670061  1791732
# 1984  1682973  1803830
# 1985  1720036  1847032
# 1986  1714664  1840164
# 1987  1737891  1865662
# 1988  1779839  1912602
# ...

# %%
df['boys'].sum()
# Out:
# 161802441

# %%
round(df['girls'].mean(), 2)
# Out:
# 1245399.21

# %%
df[df['boys'] == df['boys'].max()]['boys']
# Out:
# year
# 1957    2044160
# Name: boys, dtype: int64

# %%
df.query(f'boys==%d' % df['boys'].max())['boys']
# Out:
# year
# 1957    2044160
# Name: boys, dtype: int64

# %%
# df.loc['2000':]
df.loc[2000:]
# Out:
#          boys    girls
# year
# 2000  1814601  1962406
# 2001  1799049  1941251
# 2002  1795206  1939815
# 2003  1825359  1973434
# 2004  1834145  1982794
# 2005  1845379  1994841
# 2006  1898463  2052377
# 2007  1919408  2072139
# 2008  1887234  2036289
# 2009  1832925  1979303
# 2010  1772738  1913851
# 2011  1753500  1893230

# %%
df.query(f'year>=2000')
# Out:
#          boys    girls
# year
# 2000  1814601  1962406
# 2001  1799049  1941251
# 2002  1795206  1939815
# 2003  1825359  1973434
# 2004  1834145  1982794
# 2005  1845379  1994841
# 2006  1898463  2052377
# 2007  1919408  2072139
# 2008  1887234  2036289
# 2009  1832925  1979303
# 2010  1772738  1913851
# 2011  1753500  1893230

# %%
# df.loc['1995':'2000']
df.loc[1995:2000]
# Out:
#          boys    girls
# year
# 1995  1757927  1902832
# 1996  1752249  1893378
# 1997  1739806  1884122
# 1998  1765915  1910250
# 1999  1772632  1918809
# 2000  1814601  1962406

# %%
# df.query(f'year>=1995 and year<=2000')
df.query(f'1995 <= year <= 2000')
# Out:
#          boys    girls
# year
# 1995  1757927  1902832
# 1996  1752249  1893378
# 1997  1739806  1884122
# 1998  1765915  1910250
# 1999  1772632  1918809
# 2000  1814601  1962406

# %%
df[(df.index >= 1995) & (df.index <= 2000)]
# Out:
#          boys    girls
# year
# 1995  1757927  1902832
# 1996  1752249  1893378
# 1997  1739806  1884122
# 1998  1765915  1910250
# 1999  1772632  1918809
# 2000  1814601  1962406

# %%
df['boys'].sort_values(ascending=False).head(5)
# Out:
# year
# 1957    2044160
# 1959    2023044
# 1960    2022093
# 1961    2017316
# 1958    2010884
# Name: boys, dtype: int64

# %%
df.sort_values(by='boys', ascending=False).head(5)['boys']
# Out:
# year
# 1957    2044160
# 1959    2023044
# 1960    2022093
# 1961    2017316
# 1958    2010884
# Name: boys, dtype: int64

# %%
# df['boys_rate'] = df['boys'] / df.sum(axis=1) * 100
df['boys_rate'] = df['boys'] / (df['boys'] + df['girls']) * 100
df.tail()
# Out:
#          boys    girls  boys_rate
# year
# 2007  1919408  2072139  48.086819
# 2008  1887234  2036289  48.100495
# 2009  1832925  1979303  48.080152
# 2010  1772738  1913851  48.086131
# 2011  1753500  1893230  48.084174

# %%
# df['birth_index'] = df.loc[2000:]['boys'].apply(lambda v: '많음' if v >= 1800000 else '적음')
df['birth_index'] = df.loc[2000:].apply(lambda v: '많음' if v[0] >= 1800000 else '적음', axis = 1)

# %%
df.loc[1999:]
# Out:
#          boys    girls  boys_rate birth_index
# year
# 1999  1772632  1918809  48.020055         NaN
# 2000  1814601  1962406  48.043358          많음
# 2001  1799049  1941251  48.099056          적음
# 2002  1795206  1939815  48.064147          적음
# 2003  1825359  1973434  48.051026          많음
# 2004  1834145  1982794  48.052772          많음
# 2005  1845379  1994841  48.053992          많음
# 2006  1898463  2052377  48.052136          많음
# 2007  1919408  2072139  48.086819          많음
# 2008  1887234  2036289  48.100495          많음
# 2009  1832925  1979303  48.080152          많음
# 2010  1772738  1913851  48.086131          적음
# 2011  1753500  1893230  48.084174          적음

# %%
df.query(f'1800 <= year < 1900')[['boys', 'girls']].mean()
# Out:
# boys     176714.15
# girls    111820.55
# dtype: float64

# %%
df.query(f'1900 <= year < 2000')[['boys', 'girls']].mean()
# Out:
# boys     1362901.51
# girls    1384145.55
# dtype: float64

# %%
df.query(f'2000 <= year < 2099')[['boys', 'girls']].mean()
# Out:
# boys     1.831501e+06
# girls    1.978478e+06
# dtype: float64

# %%
average = pd.DataFrame(columns=['boys', 'girls'])
average.loc['1800s'] = df.query(f'1800 <= year < 1900')[['boys', 'girls']].mean()
average.loc['1900s'] = df.query(f'1900 <= year < 2000')[['boys', 'girls']].mean()
average.loc['2000s'] = df.query(f'2000 <= year < 2099')[['boys', 'girls']].mean()
pd.options.display.float_format = '{:.2f}'.format
average
# Out:
#             boys      girls
# 1800s  176714.15  111820.55
# 1900s 1362901.51 1384145.55
# 2000s 1831500.58 1978477.50

# %%
average.T           # trans matrix
# Out:
#           1800s      1900s      2000s
# boys  176714.15 1362901.51 1831500.58
# girls 111820.55 1384145.55 1978477.50

# %%
average.plot(kind='bar')
plt.show()
