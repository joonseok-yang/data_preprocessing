# %%
import pandas as pd
import numpy as np

# %%
def get_data():
    return [[10, 20], [30, 40], [50, 60], [70, 80]]

def get_data_frame():
    data = [[10, 20], [30, 40], [50, 60], [70, 80]]
    return pd.DataFrame(data)

def get_dict_list():
    return [{'kor': 10, 'eng': 20}, {'kor': 30, 'eng': 40}, 
            {'kor': 50, 'eng': 60}, {'kor': 70, 'eng': 80}]

def get_dict():
    return {"kor": [10, 30, 50, 70], "eng": [20, 40, 60, 80],
           'math': [33, 44, 55, 66]}

def get_dict_data_frame():
    return pd.DataFrame(get_dict(), index=['a', 'b', 'c', 'd'])

# %%
# 추가
df = get_dict_data_frame()
df['my'] = [1,2,3,4]
df
# Out:
#    kor  eng  math  my
# a   10   20    33   1
# b   30   40    44   2
# c   50   60    55   3
# d   70   80    66   4

# %%
df['my'] = df['math']
df
# Out:
#    kor  eng  math  my
# a   10   20    33  33
# b   30   40    44  44
# c   50   60    55  55
# d   70   80    66  66

# %%
df = get_dict_data_frame()
df
# Out:
#    kor  eng  math
# a   10   20    33
# b   30   40    44
# c   50   60    55
# d   70   80    66

# %%
df['sum'] = df['kor'] + df['eng'] + df['math']
df
# Out:
#    kor  eng  math  sum
# a   10   20    33   63
# b   30   40    44  114
# c   50   60    55  165
# d   70   80    66  216

# %%
df = get_dict_data_frame()
# df.loc['a'] = 2
df.loc['a'] = [1, 2, 3]
df
# Out:
#    kor  eng  math
# a    1    2     3
# b   30   40    44
# c   50   60    55
# d   70   80    66

# %%
df = get_dict_data_frame()
df.loc['e'] = [1, 2, 3]
df
# Out:
#    kor  eng  math
# a   10   20    33
# b   30   40    44
# c   50   60    55
# d   70   80    66
# e    1    2     3

# %%
df['kor']
df['kor'].sum()
df.loc['sum'] = [df['kor'].sum(), df['eng'].sum(), df['math'].sum()]
df
# Out:
#      kor  eng  math
# a     10   20    33
# b     30   40    44
# c     50   60    55
# d     70   80    66
# e      1    2     3
# sum  161  202   201

# %%
df = get_dict_data_frame()
df.loc['b':, 'sci'] = [1, 2, 3]
df
# Out:
#    kor  eng  math  sci
# a   10   20    33  NaN
# b   30   40    44  1.0
# c   50   60    55  2.0
# d   70   80    66  3.0

# %%
df.drop(columns=['kor', 'eng'])
# Out:
#    math  sci
# a    33  NaN
# b    44  1.0
# c    55  2.0
# d    66  3.0

# %%
df
# Out:
#    kor  eng  math  sci
# a   10   20    33  NaN
# b   30   40    44  1.0
# c   50   60    55  2.0
# d   70   80    66  3.0

# %%
df.drop(index='a')
# Out:
#    kor  eng  math  sci
# b   30   40    44  1.0
# c   50   60    55  2.0
# d   70   80    66  3.0

# %%
df.drop(index=['a', 'c'])
# Out:
#    kor  eng  math  sci
# b   30   40    44  1.0
# d   70   80    66  3.0

# %%
df1 = df

# %%
df1
# Out:
#    kor  eng  math  sci
# a   10   20    33  NaN
# b   30   40    44  1.0
# c   50   60    55  2.0
# d   70   80    66  3.0

# %%
df1.fillna(0, inplace=True)

# %%
df1
# Out:
#    kor  eng  math  sci
# a   10   20    33  0.0
# b   30   40    44  1.0
# c   50   60    55  2.0
# d   70   80    66  3.0

# %%
df = get_dict_data_frame()
df.loc['b':,'aaa']=[2,3,4]
df.loc['c':,'bbb']=[3,4]
df
# Out:
#    kor  eng  math  aaa  bbb
# a   10   20    33  NaN  NaN
# b   30   40    44  2.0  NaN
# c   50   60    55  3.0  3.0
# d   70   80    66  4.0  4.0

# %%
df['aaa'].fillna(0, inplace=True)
df
# Out:
#    kor  eng  math  aaa  bbb
# a   10   20    33  0.0  NaN
# b   30   40    44  2.0  NaN
# c   50   60    55  3.0  3.0
# d   70   80    66  4.0  4.0

# %%
df = get_dict_data_frame()
df.loc['b':,'aaa']=[2,3,4]
df.loc['c':,'bbb']=[3,4]
df
# Out:
#    kor  eng  math  aaa  bbb
# a   10   20    33  NaN  NaN
# b   30   40    44  2.0  NaN
# c   50   60    55  3.0  3.0
# d   70   80    66  4.0  4.0

# %%
df.dropna(axis=0)   # delete row
# Out:
#    kor  eng  math  aaa  bbb
# c   50   60    55  3.0  3.0
# d   70   80    66  4.0  4.0

# %%
df.dropna(axis=1)   # delete column
# Out:
#    kor  eng  math
# a   10   20    33
# b   30   40    44
# c   50   60    55
# d   70   80    66

# %%
df.dropna(subset=['aaa'])
# Out:
#    kor  eng  math  aaa  bbb
# b   30   40    44  2.0  NaN
# c   50   60    55  3.0  3.0
# d   70   80    66  4.0  4.0

# %%
df.dropna(subset=['bbb'])
# Out:
#    kor  eng  math  aaa  bbb
# c   50   60    55  3.0  3.0
# d   70   80    66  4.0  4.0

# %%
df.dropna(subset=['aaa', 'bbb'])
# Out:
#    kor  eng  math  aaa  bbb
# c   50   60    55  3.0  3.0
# d   70   80    66  4.0  4.0

# %%
df = get_dict_data_frame()
df
# Out:
#    kor  eng  math
# a   10   20    33
# b   30   40    44
# c   50   60    55
# d   70   80    66

# %%
df.sort_values(by='kor')
# Out:
#    kor  eng  math
# a   10   20    33
# b   30   40    44
# c   50   60    55
# d   70   80    66

# %%
df.sort_values(by=['kor', 'eng'], ascending=[True, False])
# Out:
#    kor  eng  math
# a   10   20    33
# b   30   40    44
# c   50   60    55
# d   70   80    66

# %%
df.sort_index(ascending=False)   # index 기준
# Out:
#    kor  eng  math
# d   70   80    66
# c   50   60    55
# b   30   40    44
# a   10   20    33
